# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Installing" data-toc-modified-id="Installing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Installing</a></span></li><li><span><a href="#Sample-data" data-toc-modified-id="Sample-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sample data</a></span></li><li><span><a href="#Simple-use-case" data-toc-modified-id="Simple-use-case-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Simple use case</a></span></li></ul></div>

# %% [markdown]
# # Overview
#
# This note is a document of the PlotPlayground library.
# "Simple line date series plot" of the storytelling package is the target.
#
# [Github](https://github.com/simon-ritchie/plot_playground)

# %% [markdown]
# # Installing
#
# This document uses the following versions.
# v0.0.6, Added February 10, 2019.

# %%
# !pip install plot_playground==0.0.6
# Out:
# Requirement already satisfied: plot_playground==0.0.6 in c:\users\antis\miniconda3\lib\site-packages (0.0.6)

# %% [markdown]
# # Sample data

# %%
from datetime import datetime

import pandas as pd
from pandas.tseries.offsets import Day, MonthBegin
import numpy as np

# %%
start_dt = datetime(2015, 6, 1)
last_dt = datetime(2019, 2, 1)

date_str_list = []

orange_shipment_list = []
apple_shipment_list = []
melon_shipment_list = []

orange_price_list = []
apple_price_list = []
melon_price_list = []

index = 0
target_dt = start_dt
while target_dt <= last_dt:
    target_date_str = target_dt.strftime('%Y-%m')
    date_str_list.append(target_date_str)
    orange_shipment_list.append(np.random.randint(2500, 3000))
    apple_shipment_list.append(
        int(np.random.randint(1700, 2000) + index * np.random.randint(0, 3)))
    melon_shipment_list.append(np.random.randint(1100, 1500))
    
    orange_price_list.append(np.random.randint(130, 180) / 100)
    apple_price_list.append(np.random.randint(120, 170) / 100)
    melon_price_list.append(np.random.randint(250, 450) / 100)
    target_dt += MonthBegin()
    index += 1

# %%
df = pd.DataFrame(
    columns=['date', 'orange_shipment', 'orange_price', 'apple_shipment',
             'apple_price', 'melon_shipment', 'melon_price'],
    index=np.arange(0, len(date_str_list)))

# %%
df.date = date_str_list
df.orange_shipment = orange_shipment_list
df.orange_price = orange_price_list
df.apple_shipment = apple_shipment_list
df.apple_price = apple_price_list
df.melon_shipment = melon_shipment_list
df.melon_price = melon_price_list

# %%
df
# Out:
#        date  orange_shipment  orange_price  apple_shipment  apple_price  \
# 0   2015-06             2942          1.45            1978         1.63
# 1   2015-07             2832          1.45            1741         1.23
# 2   2015-08             2800          1.72            1889         1.39
# 3   2015-09             2513          1.39            1894         1.41
# 4   2015-10             2556          1.67            1918         1.21
# 5   2015-11             2556          1.49            1746         1.49
# 6   2015-12             2535          1.68            1920         1.39
# 7   2016-01             2600          1.48            1850         1.66
# 8   2016-02             2589          1.46            1763         1.29
# 9   2016-03             2682          1.39            1931         1.47
# 10  2016-04             2877          1.34            1747         1.23
# 11  2016-05             2894          1.53            1901         1.60
# 12  2016-06             2808          1.74            1833         1.51
# 13  2016-07             2639          1.71            1768         1.20
# 14  2016-08             2880          1.38            1917         1.34
# 15  2016-09             2971          1.47            1859         1.32
# 16  2016-10             2725          1.76            1974         1.24
# 17  2016-11             2809          1.57            1930         1.39
# 18  2016-12             2789          1.60            2003         1.69
# 19  2017-01             2714          1.62            1798         1.23
# 20  2017-02             2726          1.48            1720         1.52
# 21  2017-03             2972          1.53            1761         1.61
# 22  2017-04             2693          1.61            1812         1.41
# 23  2017-05             2789          1.48            1806         1.22
# 24  2017-06             2827          1.68            1993         1.53
# 25  2017-07             2796          1.33            1971         1.59
# 26  2017-08             2639          1.72            2029         1.46
# 27  2017-09             2935          1.43            1890         1.57
# 28  2017-10             2747          1.73            1836         1.64
# 29  2017-11             2811          1.57            1793         1.41
# 30  2017-12             2998          1.63            1804         1.23
# 31  2018-01             2569          1.56            2026         1.25
# 32  2018-02             2790          1.60            1912         1.48
# 33  2018-03             2988          1.78            2042         1.63
# 34  2018-04             2604          1.64            1879         1.61
# 35  2018-05             2909          1.74            1952         1.64
# 36  2018-06             2674          1.70            1915         1.48
# 37  2018-07             2747          1.56            1961         1.20
# 38  2018-08             2740          1.60            1758         1.33
# 39  2018-09             2676          1.57            1978         1.27
# 40  2018-10             2780          1.73            1977         1.56
# 41  2018-11             2504          1.48            1738         1.66
# 42  2018-12             2529          1.38            1835         1.51
# 43  2019-01             2656          1.55            1927         1.20
# 44  2019-02             2776          1.50            1850         1.33
#
#     melon_shipment  melon_price
# 0             1187         2.73
# 1             1284         2.51
# 2             1375         2.92
# 3             1296         2.65
# 4             1235         3.69
# 5             1134         3.28
# 6             1339         2.86
# 7             1403         3.42
# 8             1388         3.11
# 9             1453         2.96
# 10            1375         2.79
# 11            1309         3.34
# 12            1395         2.71
# 13            1193         3.03
# 14            1330         2.78
# 15            1146         3.29
# 16            1356         3.93
# 17            1122         2.75
# 18            1242         2.70
# 19            1356         3.43
# 20            1493         3.35
# 21            1307         4.14
# 22            1144         2.88
# 23            1371         4.11
# 24            1200         2.72
# 25            1314         3.35
# 26            1452         3.89
# 27            1429         4.15
# 28            1240         2.60
# 29            1153         4.09
# 30            1327         3.95
# 31            1139         4.41
# 32            1380         3.43
# 33            1472         4.44
# 34            1460         3.58
# 35            1380         3.88
# 36            1390         3.64
# 37            1397         2.72
# 38            1418         4.32
# 39            1389         3.10
# 40            1367         3.75
# 41            1271         2.86
# 42            1262         4.01
# 43            1286         4.26
# 44            1468         4.32

# %% [markdown]
# # Simple use case

# %%
from plot_playground.storytelling.simple_line_date_series_plot import display_plot

# %%
display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple_shipment', 'melon_shipment'], 
    stands_out_columns=['orange_shipment'])
# Out:
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
# </script>
# <style>
#
#
# #svg_id_1549805396_09472_18841 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1549805396_09472_18841 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1549805396_09472_18841 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1549805396_09472_18841 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1549805396_09472_18841 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1549805396_09472_18841 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1549805396_09472_18841 .x-axis path,
# #svg_id_1549805396_09472_18841 .y-axis path,
# #svg_id_1549805396_09472_18841 .x-axis line,
# #svg_id_1549805396_09472_18841 .y-axis line {
#     stroke: #999999;
#     shape-rendering: crispEdges;
# }
#
# #svg_id_1549805396_09472_18841 .x-axis text,
# #svg_id_1549805396_09472_18841 .x-axis-year,
# #svg_id_1549805396_09472_18841 .y-axis text,
# #svg_id_1549805396_09472_18841 .y-axis-label {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
#     fill: #999999;
#     font-size: 14px;
# }
#
# #svg_id_1549805396_09472_18841 .line {
#     fill: none;
#     stroke: #cccccc;
#     stroke-width: 2.5;
# }
#
# #svg_id_1549805396_09472_18841 .stands-out-line {
#     fill: none;
#     stroke: #acd5ff;
#     stroke-width: 4.0;
# }
# </style>
#
# <svg id="svg_id_1549805396_09472_18841" width="600" height="372">
# </svg>
# <script>
#     require(["d3"], function(d3) {
#
#
# const SVG_ID = "svg_id_1549805396_09472_18841";
# const SVG_WIDTH = 600;
# const SVG_HEIGHT = 372;
# const SVG_BACKGROUND_COLOR = "#ffffff";
# const SVG_MARGIN_LEFT = -6;
# const OUTER_MARGIN = 20;
# const X_TICKS = 5;
# const Y_TICKS = 5;
# const Y_AXIS_PREFIX = "";
# const Y_AXIS_SUFFIX = "";
# const PLOT_TITLE_TXT = "";
# const PLOT_DESCRIPTION_TXT = "";
#
# var dateParse = d3.timeParse("%Y-%m-%d");
# var dataset = [{"date": "2015-06-01", "apple_shipment": 1978, "melon_shipment": 1187, "orange_shipment": 2942}, {"date": "2015-07-01", "apple_shipment": 1741, "melon_shipment": 1284, "orange_shipment": 2832}, {"date": "2015-08-01", "apple_shipment": 1889, "melon_shipment": 1375, "orange_shipment": 2800}, {"date": "2015-09-01", "apple_shipment": 1894, "melon_shipment": 1296, "orange_shipment": 2513}, {"date": "2015-10-01", "apple_shipment": 1918, "melon_shipment": 1235, "orange_shipment": 2556}, {"date": "2015-11-01", "apple_shipment": 1746, "melon_shipment": 1134, "orange_shipment": 2556}, {"date": "2015-12-01", "apple_shipment": 1920, "melon_shipment": 1339, "orange_shipment": 2535}, {"date": "2016-01-01", "apple_shipment": 1850, "melon_shipment": 1403, "orange_shipment": 2600}, {"date": "2016-02-01", "apple_shipment": 1763, "melon_shipment": 1388, "orange_shipment": 2589}, {"date": "2016-03-01", "apple_shipment": 1931, "melon_shipment": 1453, "orange_shipment": 2682}, {"date": "2016-04-01", "apple_shipment": 1747, "melon_shipment": 1375, "orange_shipment": 2877}, {"date": "2016-05-01", "apple_shipment": 1901, "melon_shipment": 1309, "orange_shipment": 2894}, {"date": "2016-06-01", "apple_shipment": 1833, "melon_shipment": 1395, "orange_shipment": 2808}, {"date": "2016-07-01", "apple_shipment": 1768, "melon_shipment": 1193, "orange_shipment": 2639}, {"date": "2016-08-01", "apple_shipment": 1917, "melon_shipment": 1330, "orange_shipment": 2880}, {"date": "2016-09-01", "apple_shipment": 1859, "melon_shipment": 1146, "orange_shipment": 2971}, {"date": "2016-10-01", "apple_shipment": 1974, "melon_shipment": 1356, "orange_shipment": 2725}, {"date": "2016-11-01", "apple_shipment": 1930, "melon_shipment": 1122, "orange_shipment": 2809}, {"date": "2016-12-01", "apple_shipment": 2003, "melon_shipment": 1242, "orange_shipment": 2789}, {"date": "2017-01-01", "apple_shipment": 1798, "melon_shipment": 1356, "orange_shipment": 2714}, {"date": "2017-02-01", "apple_shipment": 1720, "melon_shipment": 1493, "orange_shipment": 2726}, {"date": "2017-03-01", "apple_shipment": 1761, "melon_shipment": 1307, "orange_shipment": 2972}, {"date": "2017-04-01", "apple_shipment": 1812, "melon_shipment": 1144, "orange_shipment": 2693}, {"date": "2017-05-01", "apple_shipment": 1806, "melon_shipment": 1371, "orange_shipment": 2789}, {"date": "2017-06-01", "apple_shipment": 1993, "melon_shipment": 1200, "orange_shipment": 2827}, {"date": "2017-07-01", "apple_shipment": 1971, "melon_shipment": 1314, "orange_shipment": 2796}, {"date": "2017-08-01", "apple_shipment": 2029, "melon_shipment": 1452, "orange_shipment": 2639}, {"date": "2017-09-01", "apple_shipment": 1890, "melon_shipment": 1429, "orange_shipment": 2935}, {"date": "2017-10-01", "apple_shipment": 1836, "melon_shipment": 1240, "orange_shipment": 2747}, {"date": "2017-11-01", "apple_shipment": 1793, "melon_shipment": 1153, "orange_shipment": 2811}, {"date": "2017-12-01", "apple_shipment": 1804, "melon_shipment": 1327, "orange_shipment": 2998}, {"date": "2018-01-01", "apple_shipment": 2026, "melon_shipment": 1139, "orange_shipment": 2569}, {"date": "2018-02-01", "apple_shipment": 1912, "melon_shipment": 1380, "orange_shipment": 2790}, {"date": "2018-03-01", "apple_shipment": 2042, "melon_shipment": 1472, "orange_shipment": 2988}, {"date": "2018-04-01", "apple_shipment": 1879, "melon_shipment": 1460, "orange_shipment": 2604}, {"date": "2018-05-01", "apple_shipment": 1952, "melon_shipment": 1380, "orange_shipment": 2909}, {"date": "2018-06-01", "apple_shipment": 1915, "melon_shipment": 1390, "orange_shipment": 2674}, {"date": "2018-07-01", "apple_shipment": 1961, "melon_shipment": 1397, "orange_shipment": 2747}, {"date": "2018-08-01", "apple_shipment": 1758, "melon_shipment": 1418, "orange_shipment": 2740}, {"date": "2018-09-01", "apple_shipment": 1978, "melon_shipment": 1389, "orange_shipment": 2676}, {"date": "2018-10-01", "apple_shipment": 1977, "melon_shipment": 1367, "orange_shipment": 2780}, {"date": ...
# for (var i = 0; i < dataset.length; i++) {
#     var dataDict = dataset[i];
#     dataDict["date"] = dateParse(dataDict["date"]);
# }
# const COLUMN_LIST = ["apple_shipment", "melon_shipment"];
# const STANDS_OUT_COLUMN_LIST = ["orange_shipment"];
# var MERGED_COLUMN_LIST = COLUMN_LIST.concat(STANDS_OUT_COLUMN_LIST);
# const LEGEND_DATASET = [{"key": "apple_shipment", "value": 1850}, {"key": "melon_shipment", "value": 1468}, {"key": "orange_shipment", "value": 2776}];
# const LEGEND_KEY = function(d) {
#     return d.key;
# }
# var yearDataset = ["2015-01-01", "2016-01-01", "2017-01-01", "2018-01-01", "2019-01-01"];
# for (var i = 0; i < yearDataset.length; i++) {
#     yearDataset[i] = dateParse(yearDataset[i]);
# }
# const Y_AXIS_MIN = 0;
# const Y_AXIS_MAX = 2998 * 1.1;
# const Y_AXIS_LABEL = "";
# const X_AXIS_MIN = dateParse("2015-06-01");
# const X_AXIS_MAX = dateParse("2019-02-01");
#
# var svg = d3.select("#" + SVG_ID)
#     .style("background-color", SVG_BACKGROUND_COLOR)
#     .style("margin-left", SVG_MARGIN_LEFT);
#
# var plotBaseLineY = 0;
# if (PLOT_TITLE_TXT !== "") {
#     var plotTitle = svg.append("text")
#         .attr("x", OUTER_MARGIN)
#         .attr("y", OUTER_MARGIN)
#         .attr("dominant-baseline", "hanging")
#         .text(PLOT_TITLE_TXT)
#         .classed("title font", true);
#     var plotTitleBBox = plotTitle.node().getBBox();
#     plotBaseLineY += plotTitleBBox.y + plotTitleBBox.height;
# }
#
# if (PLOT_DESCRIPTION_TXT !== "") {
#     var plotDescription = svg.append("text")
#         .attr("x", OUTER_MARGIN)
#         .attr("y", plotBaseLineY + 10)
#         .attr("dominant-baseline", "hanging")
#         .text(PLOT_DESCR

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Installing" data-toc-modified-id="Installing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Installing</a></span></li><li><span><a href="#Sample-data" data-toc-modified-id="Sample-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sample data</a></span></li><li><span><a href="#Simple-example" data-toc-modified-id="Simple-example-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Simple example</a></span></li><li><span><a href="#Title,-description,-and-axis-label-setting-example" data-toc-modified-id="Title,-description,-and-axis-label-setting-example-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Title, description, and axis label setting example</a></span></li><li><span><a href="#Y-axis-symbol-setting-example" data-toc-modified-id="Y-axis-symbol-setting-example-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Y-axis symbol setting example</a></span></li><li><span><a href="#Black-based-color-setting" data-toc-modified-id="Black-based-color-setting-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Black-based color setting</a></span></li></ul></div>

# %% [markdown]
# # Overview
#
# This note is a document of the PlotPlayground library.
# "Simple line date series plot" of the storytelling package is the target.
# This plot is inspired by the wonderful book [Storytelling with Data: A Data Visualization Guide for Business Professionals](https://www.amazon.com/Storytelling-Data-Visualization-Business-Professionals/dp/1119002257/).
#
# [Github](https://github.com/simon-ritchie/plot_playground)

# %% [markdown]
# # Installing
#
# This document uses the following versions.
# v0.0.11, Added February 16, 2019.

# %%
# !pip install plot_playground==0.0.11
# Out:
# Requirement already satisfied: plot_playground==0.0.11 in c:\users\antis\miniconda3\lib\site-packages (0.0.11)

# %% [markdown]
# # Sample data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/simon-ritchie/plot_playground/master/documents/storytelling_simple_line_date_series_plot/dataset.csv')

# %%
df
# Out:
#           date  orange_shipment  orange_price  apple_shipment  apple_price  \
# 0   2017-06-01             2703          1.99            1861         1.21
# 1   2017-06-11             2838          2.12            1829         1.26
# 2   2017-06-21             2854          1.96            1806         1.45
# 3   2017-07-01             2974          1.98            1987         1.45
# 4   2017-07-11             2535          2.08            1936         1.37
# 5   2017-07-21             2914          2.12            2055         1.42
# 6   2017-07-31             2590          2.18            1968         1.29
# 7   2017-08-10             2947          1.97            1933         1.62
# 8   2017-08-20             2637          2.09            2025         1.51
# 9   2017-08-30             2963          2.05            2118         1.50
# 10  2017-09-09             2853          2.01            2118         1.27
# 11  2017-09-19             2923          2.12            2291         1.37
# 12  2017-09-29             2664          1.90            2305         1.69
# 13  2017-10-09             2761          2.11            2102         1.41
# 14  2017-10-19             2689          1.93            2225         1.57
# 15  2017-10-29             2534          1.92            2447         1.65
# 16  2017-11-08             2685          2.12            2208         1.26
# 17  2017-11-18             2750          2.00            2422         1.49
# 18  2017-11-28             2784          1.95            2303         1.39
# 19  2017-12-08             2722          2.09            2433         1.24
# 20  2017-12-18             2941          2.17            2518         1.43
# 21  2017-12-28             2689          1.91            2579         1.25
# 22  2018-01-07             2920          2.03            2455         1.55
# 23  2018-01-17             2999          1.90            2555         1.34
# 24  2018-01-27             2881          2.12            2440         1.49
# 25  2018-02-06             2973          2.09            2697         1.50
# 26  2018-02-16             2552          1.93            2681         1.27
# 27  2018-02-26             2725          2.15            2517         1.56
# 28  2018-03-08             2519          2.09            2595         1.61
# 29  2018-03-18             2554          2.16            2674         1.69
# ..         ...              ...           ...             ...          ...
# 32  2018-04-17             2836          2.10            2794         1.59
# 33  2018-04-27             2792          2.18            2880         1.69
# 34  2018-05-07             2789          2.01            2902         1.51
# 35  2018-05-17             2814          1.90            2982         1.30
# 36  2018-05-27             2537          1.98            2877         1.66
# 37  2018-06-06             2815          1.92            2817         1.53
# 38  2018-06-16             2710          1.97            2930         1.69
# 39  2018-06-26             2776          2.18            2955         1.69
# 40  2018-07-06             2536          2.12            3092         1.36
# 41  2018-07-16             2553          1.98            3109         1.45
# 42  2018-07-26             2565          2.07            3080         1.37
# 43  2018-08-05             2705          2.08            3071         1.41
# 44  2018-08-15             2911          2.11            3056         1.54
# 45  2018-08-25             2565          1.96            3279         1.29
# 46  2018-09-04             2880          2.09            3370         1.62
# 47  2018-09-14             2961          1.99            3289         1.43
# 48  2018-09-24             2899          1.99            3180         1.26
# 49  2018-10-04             2828          1.98            3257         1.62
# 50  2018-10-14             2980          1.96            3440         1.47
# 51  2018-10-24             2835          2.09            3343         1.46
# 52  2018-11-03             2937          2.13            3426         1.37
# 53  2018-11-13             2949          2.16            3429         1.30
# 54  2018-11-23             2567          1.98            3350         1.25
# 55  2018-12-03             2969          1.99            3404         1.49
# 56  2018-12-13             2679          2.14            3664         1.22
# 57  2018-12-23             2853          2.16            3576         1.30
# 58  2019-01-02             2953          2.19            3681         1.20
# 59  2019-01-12             2857          2.05            3593         1.35
# 60  2019-01-22             2968          2.10            3696         1.63
# 61  2019-02-01             2830          1.99            3558         1.54
#
#     melon_shipment  melon_price
# 0             1365         4.11
# 1             1246         4.12
# 2             1251         4.12
# 3             1300         4.32
# 4             1290         4.26
# 5             1291         4.10
# 6             1405         4.10
# 7             1450         4.28
# 8             1347         4.17
# 9             1153         4.41
# 10            1348         4.24
# 11            1469         4.06
# 12            1489         4.15
# 13            1393         4.38
# 14            1358         4.27
# 15            1284         4.35
# 16            1297         4.34
# 17            1484         4.19
# 18            1132         4.32
# 19            1254         4.17
# 20            1464         4.21
# 21            1251         4.28
# 22            1468         4.08
# 23            1260         4.38
# 24            1415         4.43
# 25            1248         4.37
# 26            1441         4.26
# 27            1277         4.05
# 28            1302         4.26
# 29            1207         4.02
# ..             ...          ...
# 32            1374         4.17
# 33            1146         4.22
# 34            1290         4.05
# 35            1312         4.33
# 36            1384         4.17
# 37            1114         4.17
# 38            1256         4.26
# 39            1184         4.11
# 40            1228         4.05
# 41            1393         4.23
# 42            1464         4.27
# 43            1211         4.35
# 44            1491         4.32
# 45            1136         4.49
# 46            1408         4.21
# 47            1205         4.15
# 48            1493         4.28
# 49            1191         4.44
# 50            1350         4.47
# 51            1243         4.01
# 52            1220         4.47
# 53            1147         4.09
# 54            1337         4.34
# 55            1482         4.44
# 56            1492         4.11
# 57            1341         4.24
# 58            1265         4.16
# 59            1302         4.20
# 60            1227         4.24
# 61            1319         4.05
#
# [62 rows x 7 columns]

# %% [markdown]
# # Simple example
#
# - The date column (date_column) allows a string of the form 2019-02-11, or a type value such as datetime. You can also specify it in the same way in the month format (e.g., 2019-02).
# - Please specify the column you want to highlight (blue line in this example) with the stands_out_columns argument.
# - Columns specified by the normal_columns argument are displayed as inconspicuous colors (gray in this example).

# %%
from plot_playground.storytelling.simple_line_date_series_plot import display_plot

# %%
display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple_shipment', 'melon_shipment'], 
    stands_out_columns=['orange_shipment'])
# Out:
# <style>
#
#
# #svg_id_1550291373_058344_97745 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1550291373_058344_97745 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1550291373_058344_97745 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1550291373_058344_97745 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_058344_97745 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_058344_97745 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1550291373_058344_97745 .x-axis path,
# #svg_id_1550291373_058344_97745 .y-axis path,
# #svg_id_1550291373_058344_97745 .x-axis line,
# #svg_id_1550291373_058344_97745 .y-axis line {
#     stroke: #999999;
#     shape-rendering: crispEdges;
# }
#
# #svg_id_1550291373_058344_97745 .x-axis text,
# #svg_id_1550291373_058344_97745 .x-axis-year,
# #svg_id_1550291373_058344_97745 .y-axis text,
# #svg_id_1550291373_058344_97745 .y-axis-label {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
#     fill: #999999;
#     font-size: 14px;
# }
#
# #svg_id_1550291373_058344_97745 .line {
#     fill: none;
#     stroke: #e8e8e8;
#     stroke-width: 2.5;
# }
#
# #svg_id_1550291373_058344_97745 .stands-out-line {
#     fill: none;
#     stroke: #acd5ff;
#     stroke-width: 4.0;
# }
# </style>
#
# <svg id="svg_id_1550291373_058344_97745" width="600" height="372">
# </svg>
# <script src="/static/components/requirejs/require.js"></script>
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
#     require(["d3"], function(d3) {
#         var svgParent = d3.select("#svg_id_1550291373_058344_97745")
#             .select(function() {
#                 return this.parentNode;
#             })
#             .style("padding-left", 0);
#
#
# const SVG_ID = "svg_id_1550291373_058344_97745";
# const SVG_WIDTH = 600;
# const SVG_HEIGHT = 372;
# const SVG_BACKGROUND_COLOR = "#ffffff";
# const SVG_MARGIN_LEFT = 0;
# const OUTER_MARGIN = 20;
# const X_TICKS = 5;
# const Y_TICKS = 5;
# const Y_AXIS_PREFIX = "";
# const Y_AXIS_SUFFIX = "";
# const PLOT_TITLE_TXT = "";
# const PLOT_DESCRIPTION_TXT = "";
#
# var dateParse = d3.timeParse("%Y-%m-%d");
# var dataset = [{"date": "2017-06-01", "apple_shipment": 1861, "melon_shipment": 1365, "orange_shipment": 2703}, {"date": "2017-06-11", "apple_shipment": 1829, "melon_shipment": 1246, "orange_shipment": 2838}, {"date": "2017-06-21", "apple_shipment": 1806, "melon_shipment": 1251, "orange_shipment": 2854}, {"date": "2017-07-01", "apple_shipment": 1987, "melon_shipment": 1300, "orange_shipment": 2974}, {"date": "2017-07-11", "apple_shipment": 1936, "melon_shipment": 1290, "orange_shipment": 2535}, {"date": "2017-07-21", "apple_shipment": 2055, "melon_shipment": 1291, "orange_shipment": 2914}, {"date": "2017-07-31", "apple_shipment": 1968, "melon_shipment": 1405, "orange_shipment": 2590}, {"date": "2017-08-10", "apple_shipment": 1933, "melon_shipment": 1450, "orange_shipment": 2947}, {"date": "2017-08-20", "apple_shipment": 2025, "melon_shipment": 1347, "orange_shipment": 2637}, {"date": "2017-08-30", "apple_shipment": 2118, "melon_shipment": 1153, "orange_shipment": 2963}, {"date": "2017-09-09", "apple_shipment": 2118, "melon_shipment": 1348, "orange_shipment": 2853}, {"date": "2017-09-19", "apple_shipment": 2291, "melon_shipment": 1469, "orange_shipment": 2923}, {"date": "2017-09-29", "apple_shipment": 2305, "melon_shipment": 1489, "orange_shipment": 2664}, {"date": "2017-10-09", "apple_shipment": 2102, "melon_shipment": 1393, "orange_shipment": 2761}, {"date": "2017-10-19", "apple_shipment": 2225, "melon_shipment": 1358, "orange_shipment": 2689}, {"date": "2017-10-29", "apple_shipment": 2447, "melon_shipment": 1284, "orange_shipment": 2534}, {"date": "2017-11-08", "apple_shipment": 2208, "melon_shipment": 1297, "orange_shipment": 2685}, {"date": "2017-11-18", "apple_shipment": 2422, "melon_shipment": 1484, "orange_shipment": 2750}, {"date": "2017-11-28", "apple_shipment": 2303, "melon_shipment": 1132, "orange_shipment": 2784}, {"date": "2017-12-08", "apple_shipment": 2433, "melon_shipment": 1254, "orange_shipment": 2722}, {"date": "2017-12-18", "apple_shipment": 2518, "melon_shipment": 1464, "orange_shipment": 2941}, {"date": "2017-12-28", "apple_shipment": 2579, "melon_shipment": 1251, "orange_shipment": 2689}, {"date": "2018-01-07", "apple_shipment": 2455, "melon_shipment": 1468, "orange_shipment": 2920}, {"date": "2018-01-17", "apple_shipment": 2555, "melon_shipment": 1260, "orange_shipment": 2999}, {"date": "2018-01-27", "apple_shipment": 2440, "melon_shipment": 1415, "orange_shipment": 2881}, {"date": "2018-02-06", "apple_shipment": 2697, "melon_shipment": 1248, "orange_shipment": 2973}, {"date": "2018-02-16", "apple_shipment": 2681, "melon_shipment": 1441, "orange_shipment": 2552}, {"date": "2018-02-26", "apple_shipment": 2517, "melon_shipment": 1277, "orange_shipment": 2725}, {"date": "2018-03-08", "apple_shipment": 2595, "melon_shipment": 1302, "orange_shipment": 2519}, {"date": "2018-03-18", "apple_shipment": 2674, "melon_shipment": 1207, "orange_shipment": 2554}, {"date": "2018-03-28", "apple_shipment": 2725, "melon_shipment": 1400, "orange_shipment": 2746}, {"date": "2018-04-07", "apple_shipment": 2908, "melon_shipment": 1492, "orange_shipment": 2845}, {"date": "2018-04-17", "apple_shipment": 2794, "melon_shipment": 1374, "orange_shipment": 2836}, {"date": "2018-04-27", "apple_shipment": 2880, "melon_shipment": 1146, "orange_shipment": 2792}, {"date": "2018-05-07", "apple_shipment": 2902, "melon_shipment": 1290, "orange_shipment": 2789}, {"date": "2018-05-17", "apple_shipment": 2982, "melon_shipment": 1312, "orange_shipment": 2814}, {"date": "2018-05-27", "apple_shipment": 2877, "melon_shipment": 1384, "orange_shipment": 2537}, {"date": "2018-06-06", "apple_shipment": 2817, "melon_shipment": 1114, "orange_shipment": 2815}, {"date": "2018-06-16", "apple_shipment": 2930, "melon_shipment": 1256, "orange_shipment": 2710}, {"date": "2018-06-26", "apple_shipment": 2955, "melon_shipment": 1184, "orange_shipment": 2776}, {"date": "2018-07-06", "apple_shipment": 3092, "melon_shipment": 1228, "orange_shipment": 2536}, {"date": ...

# %% [markdown]
# # Title, description, and axis label setting example
#
# - If the title, description, y_axis_label arguments are specified, they are placed in the plot and the layout is adjusted.

# %%
display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple_shipment', 'melon_shipment'], 
    stands_out_columns=['orange_shipment'],
    title='Fruit shipment volume',
    description='Orange shipment volumes have not changed much in the past year and a half.',
    y_axis_label='shipment volume')
# Out:
# <style>
#
#
# #svg_id_1550291373_145346_74301 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1550291373_145346_74301 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1550291373_145346_74301 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1550291373_145346_74301 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_145346_74301 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_145346_74301 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1550291373_145346_74301 .x-axis path,
# #svg_id_1550291373_145346_74301 .y-axis path,
# #svg_id_1550291373_145346_74301 .x-axis line,
# #svg_id_1550291373_145346_74301 .y-axis line {
#     stroke: #999999;
#     shape-rendering: crispEdges;
# }
#
# #svg_id_1550291373_145346_74301 .x-axis text,
# #svg_id_1550291373_145346_74301 .x-axis-year,
# #svg_id_1550291373_145346_74301 .y-axis text,
# #svg_id_1550291373_145346_74301 .y-axis-label {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
#     fill: #999999;
#     font-size: 14px;
# }
#
# #svg_id_1550291373_145346_74301 .line {
#     fill: none;
#     stroke: #e8e8e8;
#     stroke-width: 2.5;
# }
#
# #svg_id_1550291373_145346_74301 .stands-out-line {
#     fill: none;
#     stroke: #acd5ff;
#     stroke-width: 4.0;
# }
# </style>
#
# <svg id="svg_id_1550291373_145346_74301" width="600" height="372">
# </svg>
# <script src="/static/components/requirejs/require.js"></script>
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
#     require(["d3"], function(d3) {
#         var svgParent = d3.select("#svg_id_1550291373_145346_74301")
#             .select(function() {
#                 return this.parentNode;
#             })
#             .style("padding-left", 0);
#
#
# const SVG_ID = "svg_id_1550291373_145346_74301";
# const SVG_WIDTH = 600;
# const SVG_HEIGHT = 372;
# const SVG_BACKGROUND_COLOR = "#ffffff";
# const SVG_MARGIN_LEFT = 0;
# const OUTER_MARGIN = 20;
# const X_TICKS = 5;
# const Y_TICKS = 5;
# const Y_AXIS_PREFIX = "";
# const Y_AXIS_SUFFIX = "";
# const PLOT_TITLE_TXT = "Fruit shipment volume";
# const PLOT_DESCRIPTION_TXT = "Orange shipment volumes have not changed much in the past year and a half.";
#
# var dateParse = d3.timeParse("%Y-%m-%d");
# var dataset = [{"date": "2017-06-01", "apple_shipment": 1861, "melon_shipment": 1365, "orange_shipment": 2703}, {"date": "2017-06-11", "apple_shipment": 1829, "melon_shipment": 1246, "orange_shipment": 2838}, {"date": "2017-06-21", "apple_shipment": 1806, "melon_shipment": 1251, "orange_shipment": 2854}, {"date": "2017-07-01", "apple_shipment": 1987, "melon_shipment": 1300, "orange_shipment": 2974}, {"date": "2017-07-11", "apple_shipment": 1936, "melon_shipment": 1290, "orange_shipment": 2535}, {"date": "2017-07-21", "apple_shipment": 2055, "melon_shipment": 1291, "orange_shipment": 2914}, {"date": "2017-07-31", "apple_shipment": 1968, "melon_shipment": 1405, "orange_shipment": 2590}, {"date": "2017-08-10", "apple_shipment": 1933, "melon_shipment": 1450, "orange_shipment": 2947}, {"date": "2017-08-20", "apple_shipment": 2025, "melon_shipment": 1347, "orange_shipment": 2637}, {"date": "2017-08-30", "apple_shipment": 2118, "melon_shipment": 1153, "orange_shipment": 2963}, {"date": "2017-09-09", "apple_shipment": 2118, "melon_shipment": 1348, "orange_shipment": 2853}, {"date": "2017-09-19", "apple_shipment": 2291, "melon_shipment": 1469, "orange_shipment": 2923}, {"date": "2017-09-29", "apple_shipment": 2305, "melon_shipment": 1489, "orange_shipment": 2664}, {"date": "2017-10-09", "apple_shipment": 2102, "melon_shipment": 1393, "orange_shipment": 2761}, {"date": "2017-10-19", "apple_shipment": 2225, "melon_shipment": 1358, "orange_shipment": 2689}, {"date": "2017-10-29", "apple_shipment": 2447, "melon_shipment": 1284, "orange_shipment": 2534}, {"date": "2017-11-08", "apple_shipment": 2208, "melon_shipment": 1297, "orange_shipment": 2685}, {"date": "2017-11-18", "apple_shipment": 2422, "melon_shipment": 1484, "orange_shipment": 2750}, {"date": "2017-11-28", "apple_shipment": 2303, "melon_shipment": 1132, "orange_shipment": 2784}, {"date": "2017-12-08", "apple_shipment": 2433, "melon_shipment": 1254, "orange_shipment": 2722}, {"date": "2017-12-18", "apple_shipment": 2518, "melon_shipment": 1464, "orange_shipment": 2941}, {"date": "2017-12-28", "apple_shipment": 2579, "melon_shipment": 1251, "orange_shipment": 2689}, {"date": "2018-01-07", "apple_shipment": 2455, "melon_shipment": 1468, "orange_shipment": 2920}, {"date": "2018-01-17", "apple_shipment": 2555, "melon_shipment": 1260, "orange_shipment": 2999}, {"date": "2018-01-27", "apple_shipment": 2440, "melon_shipment": 1415, "orange_shipment": 2881}, {"date": "2018-02-06", "apple_shipment": 2697, "melon_shipment": 1248, "orange_shipment": 2973}, {"date": "2018-02-16", "apple_shipment": 2681, "melon_shipment": 1441, "orange_shipment": 2552}, {"date": "2018-02-26", "apple_shipment": 2517, "melon_shipment": 1277, "orange_shipment": 2725}, {"date": "2018-03-08", "apple_shipment": 2595, "melon_shipment": 1302, "orange_shipment": 2519}, {"date": "2018-03-18", "apple_shipment": 2674, "melon_shipment": 1207, "orange_shipment": 2554}, {"date": "2018-03-28", "apple_shipment": 2725, "melon_shipment": 1400, "orange_shipment": 2746}, {"date": "2018-04-07", "apple_shipment": 2908, "melon_shipment": 1492, "orange_shipment": 2845}, {"date": "2018-04-17", "apple_shipment": 2794, "melon_shipment": 1374, "orange_shipment": 2836}, {"date": "2018-04-27", "apple_shipment": 2880, "melon_shipment": 1146, "orange_shipment": 2792}, {"date": "2018-05-07", "apple_shipment": 2902, "melon_shipment": 1290, "orange_shipment": 2789}, {"date": "2018-05-17", "apple_shipment": 2982, "melon_shipment": 1312, "orange_shipment": 2814}, {"date": "2018-05-27", "apple_shipment": 2877, "melon_shipment": 1384, "orange_shipment": 2537}, {"date": "2018-06-06", "apple_shipment": 2817, "melon_shipment": 1114, "orange_shipment": 2815}, {"date": "2018-06-16", "apple_shipment": 2930, "melon_shipment": 1256, "orange_shipment": 2710}, {"date": "2018-06-26", "apple_shipment": 2955, "melon_shipment": 1184, "orange_shipment": 2776}, {"date": "2018-07-06", "apple_shipment": 3092, "melon_shipment": 1228, "orange_shipment": 2536}, {"date": ...

# %% [markdown]
# # Y-axis symbol setting example
#
# - In some cases it may be more user-friendly to add a symbol to the y-axis value. (e.g., \$ or %)
# - An arbitrary symbol can be given by specifying the y_axis_ prefix or y_axis_suffix argument.

# %%
display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple_price', 'melon_price'], 
    stands_out_columns=['orange_price'],
    title='Average trend of fruit price',
    description='Orange price have not changed much in the past year and a half.',
    y_axis_prefix='$')
# Out:
# <style>
#
#
# #svg_id_1550291373_243347_72138 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1550291373_243347_72138 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1550291373_243347_72138 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1550291373_243347_72138 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_243347_72138 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_243347_72138 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1550291373_243347_72138 .x-axis path,
# #svg_id_1550291373_243347_72138 .y-axis path,
# #svg_id_1550291373_243347_72138 .x-axis line,
# #svg_id_1550291373_243347_72138 .y-axis line {
#     stroke: #999999;
#     shape-rendering: crispEdges;
# }
#
# #svg_id_1550291373_243347_72138 .x-axis text,
# #svg_id_1550291373_243347_72138 .x-axis-year,
# #svg_id_1550291373_243347_72138 .y-axis text,
# #svg_id_1550291373_243347_72138 .y-axis-label {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
#     fill: #999999;
#     font-size: 14px;
# }
#
# #svg_id_1550291373_243347_72138 .line {
#     fill: none;
#     stroke: #e8e8e8;
#     stroke-width: 2.5;
# }
#
# #svg_id_1550291373_243347_72138 .stands-out-line {
#     fill: none;
#     stroke: #acd5ff;
#     stroke-width: 4.0;
# }
# </style>
#
# <svg id="svg_id_1550291373_243347_72138" width="600" height="372">
# </svg>
# <script src="/static/components/requirejs/require.js"></script>
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
#     require(["d3"], function(d3) {
#         var svgParent = d3.select("#svg_id_1550291373_243347_72138")
#             .select(function() {
#                 return this.parentNode;
#             })
#             .style("padding-left", 0);
#
#
# const SVG_ID = "svg_id_1550291373_243347_72138";
# const SVG_WIDTH = 600;
# const SVG_HEIGHT = 372;
# const SVG_BACKGROUND_COLOR = "#ffffff";
# const SVG_MARGIN_LEFT = 0;
# const OUTER_MARGIN = 20;
# const X_TICKS = 5;
# const Y_TICKS = 5;
# const Y_AXIS_PREFIX = "$";
# const Y_AXIS_SUFFIX = "";
# const PLOT_TITLE_TXT = "Average trend of fruit price";
# const PLOT_DESCRIPTION_TXT = "Orange price have not changed much in the past year and a half.";
#
# var dateParse = d3.timeParse("%Y-%m-%d");
# var dataset = [{"date": "2017-06-01", "apple_price": 1.21, "melon_price": 4.11, "orange_price": 1.99}, {"date": "2017-06-11", "apple_price": 1.26, "melon_price": 4.12, "orange_price": 2.12}, {"date": "2017-06-21", "apple_price": 1.45, "melon_price": 4.12, "orange_price": 1.96}, {"date": "2017-07-01", "apple_price": 1.45, "melon_price": 4.32, "orange_price": 1.98}, {"date": "2017-07-11", "apple_price": 1.37, "melon_price": 4.26, "orange_price": 2.08}, {"date": "2017-07-21", "apple_price": 1.42, "melon_price": 4.1, "orange_price": 2.12}, {"date": "2017-07-31", "apple_price": 1.29, "melon_price": 4.1, "orange_price": 2.18}, {"date": "2017-08-10", "apple_price": 1.62, "melon_price": 4.28, "orange_price": 1.97}, {"date": "2017-08-20", "apple_price": 1.51, "melon_price": 4.17, "orange_price": 2.09}, {"date": "2017-08-30", "apple_price": 1.5, "melon_price": 4.41, "orange_price": 2.05}, {"date": "2017-09-09", "apple_price": 1.27, "melon_price": 4.24, "orange_price": 2.01}, {"date": "2017-09-19", "apple_price": 1.37, "melon_price": 4.06, "orange_price": 2.12}, {"date": "2017-09-29", "apple_price": 1.69, "melon_price": 4.15, "orange_price": 1.9}, {"date": "2017-10-09", "apple_price": 1.41, "melon_price": 4.38, "orange_price": 2.11}, {"date": "2017-10-19", "apple_price": 1.57, "melon_price": 4.27, "orange_price": 1.93}, {"date": "2017-10-29", "apple_price": 1.65, "melon_price": 4.35, "orange_price": 1.92}, {"date": "2017-11-08", "apple_price": 1.26, "melon_price": 4.34, "orange_price": 2.12}, {"date": "2017-11-18", "apple_price": 1.49, "melon_price": 4.19, "orange_price": 2.0}, {"date": "2017-11-28", "apple_price": 1.39, "melon_price": 4.32, "orange_price": 1.95}, {"date": "2017-12-08", "apple_price": 1.24, "melon_price": 4.17, "orange_price": 2.09}, {"date": "2017-12-18", "apple_price": 1.43, "melon_price": 4.21, "orange_price": 2.17}, {"date": "2017-12-28", "apple_price": 1.25, "melon_price": 4.28, "orange_price": 1.91}, {"date": "2018-01-07", "apple_price": 1.55, "melon_price": 4.08, "orange_price": 2.03}, {"date": "2018-01-17", "apple_price": 1.34, "melon_price": 4.38, "orange_price": 1.9}, {"date": "2018-01-27", "apple_price": 1.49, "melon_price": 4.43, "orange_price": 2.12}, {"date": "2018-02-06", "apple_price": 1.5, "melon_price": 4.37, "orange_price": 2.09}, {"date": "2018-02-16", "apple_price": 1.27, "melon_price": 4.26, "orange_price": 1.93}, {"date": "2018-02-26", "apple_price": 1.56, "melon_price": 4.05, "orange_price": 2.15}, {"date": "2018-03-08", "apple_price": 1.61, "melon_price": 4.26, "orange_price": 2.09}, {"date": "2018-03-18", "apple_price": 1.69, "melon_price": 4.02, "orange_price": 2.16}, {"date": "2018-03-28", "apple_price": 1.69, "melon_price": 4.46, "orange_price": 1.99}, {"date": "2018-04-07", "apple_price": 1.58, "melon_price": 4.35, "orange_price": 2.14}, {"date": "2018-04-17", "apple_price": 1.59, "melon_price": 4.17, "orange_price": 2.1}, {"date": "2018-04-27", "apple_price": 1.69, "melon_price": 4.22, "orange_price": 2.18}, {"date": "2018-05-07", "apple_price": 1.51, "melon_price": 4.05, "orange_price": 2.01}, {"date": "2018-05-17", "apple_price": 1.3, "melon_price": 4.33, "orange_price": 1.9}, {"date": "2018-05-27", "apple_price": 1.66, "melon_price": 4.17, "orange_price": 1.98}, {"date": "2018-06-06", "apple_price": 1.53, "melon_price": 4.17, "orange_price": 1.92}, {"date": "2018-06-16", "apple_price": 1.69, "melon_price": 4.26, "orange_price": 1.97}, {"date": "2018-06-26", "apple_price": 1.69, "melon_price": 4.11, "orange_price": 2.18}, {"date": "2018-07-06", "apple_price": 1.36, "melon_price": 4.05, "orange_price": 2.12}, {"date": "2018-07-16", "apple_price": 1.45, "melon_price": 4.23, "orange_price": 1.98}, {"date": "2018-07-26", "apple_price": 1.37, "melon_price": 4.27, "orange_price": 2.07}, {"date": "2018-08-05", "apple_price": 1.41, "melon_price": 4.35, "orange_price": 2.08}, {"date": "2018-08-15", "apple_price": 1.54, "melon_price": 4.32, "orange_price": 2.11}, {"date": "2018-08-25", "apple_price ...
# for (var i = 0; i < dataset.length; i++) {
#     var da

# %% [markdown]
# # Black-based color setting
#
# - If necessary, you can change the color and other styles by adjusting the value of the optional argument.
# - Color settings are specified in hexadecimal notation like CSS (e.g., #555555).
# - Size specification is set in pixel units.

# %%
display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple_price', 'melon_price'], 
    stands_out_columns=['orange_price'],
    title='Average trend of fruit price',
    description='Orange price have not changed much in the past year and a half.',
    y_axis_prefix='$',
    plot_background_color='#333333',
    line_color='#555555',
    stands_out_line_color='#6bb2f8')
# Out:
# <style>
#
#
# #svg_id_1550291373_338344_22220 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1550291373_338344_22220 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1550291373_338344_22220 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1550291373_338344_22220 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_338344_22220 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1550291373_338344_22220 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1550291373_338344_22220 .x-axis path,
# #svg_id_1550291373_338344_22220 .y-axis path,
# #svg_id_1550291373_338344_22220 .x-axis line,
# #svg_id_1550291373_338344_22220 .y-axis line {
#     stroke: #999999;
#     shape-rendering: crispEdges;
# }
#
# #svg_id_1550291373_338344_22220 .x-axis text,
# #svg_id_1550291373_338344_22220 .x-axis-year,
# #svg_id_1550291373_338344_22220 .y-axis text,
# #svg_id_1550291373_338344_22220 .y-axis-label {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
#     fill: #999999;
#     font-size: 14px;
# }
#
# #svg_id_1550291373_338344_22220 .line {
#     fill: none;
#     stroke: #555555;
#     stroke-width: 2.5;
# }
#
# #svg_id_1550291373_338344_22220 .stands-out-line {
#     fill: none;
#     stroke: #6bb2f8;
#     stroke-width: 4.0;
# }
# </style>
#
# <svg id="svg_id_1550291373_338344_22220" width="600" height="372">
# </svg>
# <script src="/static/components/requirejs/require.js"></script>
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
#     require(["d3"], function(d3) {
#         var svgParent = d3.select("#svg_id_1550291373_338344_22220")
#             .select(function() {
#                 return this.parentNode;
#             })
#             .style("padding-left", 0);
#
#
# const SVG_ID = "svg_id_1550291373_338344_22220";
# const SVG_WIDTH = 600;
# const SVG_HEIGHT = 372;
# const SVG_BACKGROUND_COLOR = "#333333";
# const SVG_MARGIN_LEFT = 0;
# const OUTER_MARGIN = 20;
# const X_TICKS = 5;
# const Y_TICKS = 5;
# const Y_AXIS_PREFIX = "$";
# const Y_AXIS_SUFFIX = "";
# const PLOT_TITLE_TXT = "Average trend of fruit price";
# const PLOT_DESCRIPTION_TXT = "Orange price have not changed much in the past year and a half.";
#
# var dateParse = d3.timeParse("%Y-%m-%d");
# var dataset = [{"date": "2017-06-01", "apple_price": 1.21, "melon_price": 4.11, "orange_price": 1.99}, {"date": "2017-06-11", "apple_price": 1.26, "melon_price": 4.12, "orange_price": 2.12}, {"date": "2017-06-21", "apple_price": 1.45, "melon_price": 4.12, "orange_price": 1.96}, {"date": "2017-07-01", "apple_price": 1.45, "melon_price": 4.32, "orange_price": 1.98}, {"date": "2017-07-11", "apple_price": 1.37, "melon_price": 4.26, "orange_price": 2.08}, {"date": "2017-07-21", "apple_price": 1.42, "melon_price": 4.1, "orange_price": 2.12}, {"date": "2017-07-31", "apple_price": 1.29, "melon_price": 4.1, "orange_price": 2.18}, {"date": "2017-08-10", "apple_price": 1.62, "melon_price": 4.28, "orange_price": 1.97}, {"date": "2017-08-20", "apple_price": 1.51, "melon_price": 4.17, "orange_price": 2.09}, {"date": "2017-08-30", "apple_price": 1.5, "melon_price": 4.41, "orange_price": 2.05}, {"date": "2017-09-09", "apple_price": 1.27, "melon_price": 4.24, "orange_price": 2.01}, {"date": "2017-09-19", "apple_price": 1.37, "melon_price": 4.06, "orange_price": 2.12}, {"date": "2017-09-29", "apple_price": 1.69, "melon_price": 4.15, "orange_price": 1.9}, {"date": "2017-10-09", "apple_price": 1.41, "melon_price": 4.38, "orange_price": 2.11}, {"date": "2017-10-19", "apple_price": 1.57, "melon_price": 4.27, "orange_price": 1.93}, {"date": "2017-10-29", "apple_price": 1.65, "melon_price": 4.35, "orange_price": 1.92}, {"date": "2017-11-08", "apple_price": 1.26, "melon_price": 4.34, "orange_price": 2.12}, {"date": "2017-11-18", "apple_price": 1.49, "melon_price": 4.19, "orange_price": 2.0}, {"date": "2017-11-28", "apple_price": 1.39, "melon_price": 4.32, "orange_price": 1.95}, {"date": "2017-12-08", "apple_price": 1.24, "melon_price": 4.17, "orange_price": 2.09}, {"date": "2017-12-18", "apple_price": 1.43, "melon_price": 4.21, "orange_price": 2.17}, {"date": "2017-12-28", "apple_price": 1.25, "melon_price": 4.28, "orange_price": 1.91}, {"date": "2018-01-07", "apple_price": 1.55, "melon_price": 4.08, "orange_price": 2.03}, {"date": "2018-01-17", "apple_price": 1.34, "melon_price": 4.38, "orange_price": 1.9}, {"date": "2018-01-27", "apple_price": 1.49, "melon_price": 4.43, "orange_price": 2.12}, {"date": "2018-02-06", "apple_price": 1.5, "melon_price": 4.37, "orange_price": 2.09}, {"date": "2018-02-16", "apple_price": 1.27, "melon_price": 4.26, "orange_price": 1.93}, {"date": "2018-02-26", "apple_price": 1.56, "melon_price": 4.05, "orange_price": 2.15}, {"date": "2018-03-08", "apple_price": 1.61, "melon_price": 4.26, "orange_price": 2.09}, {"date": "2018-03-18", "apple_price": 1.69, "melon_price": 4.02, "orange_price": 2.16}, {"date": "2018-03-28", "apple_price": 1.69, "melon_price": 4.46, "orange_price": 1.99}, {"date": "2018-04-07", "apple_price": 1.58, "melon_price": 4.35, "orange_price": 2.14}, {"date": "2018-04-17", "apple_price": 1.59, "melon_price": 4.17, "orange_price": 2.1}, {"date": "2018-04-27", "apple_price": 1.69, "melon_price": 4.22, "orange_price": 2.18}, {"date": "2018-05-07", "apple_price": 1.51, "melon_price": 4.05, "orange_price": 2.01}, {"date": "2018-05-17", "apple_price": 1.3, "melon_price": 4.33, "orange_price": 1.9}, {"date": "2018-05-27", "apple_price": 1.66, "melon_price": 4.17, "orange_price": 1.98}, {"date": "2018-06-06", "apple_price": 1.53, "melon_price": 4.17, "orange_price": 1.92}, {"date": "2018-06-16", "apple_price": 1.69, "melon_price": 4.26, "orange_price": 1.97}, {"date": "2018-06-26", "apple_price": 1.69, "melon_price": 4.11, "orange_price": 2.18}, {"date": "2018-07-06", "apple_price": 1.36, "melon_price": 4.05, "orange_price": 2.12}, {"date": "2018-07-16", "apple_price": 1.45, "melon_price": 4.23, "orange_price": 1.98}, {"date": "2018-07-26", "apple_price": 1.37, "melon_price": 4.27, "orange_price": 2.07}, {"date": "2018-08-05", "apple_price": 1.41, "melon_price": 4.35, "orange_price": 2.08}, {"date": "2018-08-15", "apple_price": 1.54, "melon_price": 4.32, "orange_price": 2.11}, {"date": "2018-08-25", "apple_price ...
# for (var i = 0; i < dataset.length; i++) {
#     var da

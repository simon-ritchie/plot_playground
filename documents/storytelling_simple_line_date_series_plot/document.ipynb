# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#Version-added-and-installing" data-toc-modified-id="Version-added-and-installing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Version added and installing</a></span></li><li><span><a href="#Sample-data" data-toc-modified-id="Sample-data-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sample data</a></span></li><li><span><a href="#Simple-use-case" data-toc-modified-id="Simple-use-case-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Simple use case</a></span></li></ul></div>

# %% [markdown]
# # Overview
#
# This note is a document of the PlotPlayground library.
# "Simple line date series plot" of the storytelling package is the target.
#
# [Github](https://github.com/simon-ritchie/plot_playground)

# %% [markdown]
# # Version added and installing
#
# v0.0.5, Released February 9, 2019.

# %%
# !pip install plot_playground==0.0.5
# Out:
# Collecting plot_playground==0.0.5
#   Downloading https://files.pythonhosted.org/packages/41/47/94cf08ed75edb22db57bbb973211a88c8262421faf71e579e5db401d6ed5/plot_playground-0.0.5-py3-none-any.whl
# Installing collected packages: plot-playground
# Successfully installed plot-playground-0.0.5
# You are using pip version 10.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# # Sample data

# %%
from datetime import datetime

import pandas as pd
from pandas.tseries.offsets import Day, MonthBegin
import numpy as np

# %%
start_dt = datetime(2015, 6, 1)
last_dt = datetime(2019, 2, 1)

date_str_list = []

orange_shipment_list = []
apple_shipment_list = []
melon_shipment_list = []

orange_price_list = []
apple_price_list = []
melon_price_list = []

index = 0
target_dt = start_dt
while target_dt <= last_dt:
    target_date_str = target_dt.strftime('%Y-%m')
    date_str_list.append(target_date_str)
    orange_shipment_list.append(np.random.randint(1000, 3000))
    apple_shipment_list.append(
        int(np.random.randint(1000, 2000) + index / 3 * np.random.randint(0, 3)))
    melon_shipment_list.append(np.random.randint(300, 1500))
    
    orange_price_list.append(np.random.randint(130, 180) / 100)
    apple_price_list.append(np.random.randint(120, 170) / 100)
    melon_price_list.append(np.random.randint(250, 450) / 100)
    target_dt += MonthBegin()
    index += 1

# %%
len(date_str_list)
# Out:
# 45

# %%
len(orange_shipment_list)
# Out:
# 45

# %%
df = pd.DataFrame(
    columns=['date', 'orange_shipment', 'orange_price', 'apple_shipment',
             'apple_price', 'melon_shipment', 'melon_price'],
    index=np.arange(0, len(date_str_list)))

# %%
df.date = date_str_list
df.orange_shipment = orange_shipment_list
df.orange_price = orange_price_list
df.apple_shipment = apple_shipment_list
df.apple_price = apple_price_list
df.melon_shipment = melon_shipment_list
df.melon_price = melon_price_list

# %%
df
# Out:
#        date  orange_shipment  orange_price  apple_shipment  apple_price  \
# 0   2015-06             1582          1.79            1012         1.43
# 1   2015-07             1942          1.46            1269         1.44
# 2   2015-08             2122          1.61            1939         1.30
# 3   2015-09             2219          1.79            1506         1.49
# 4   2015-10             1234          1.56            1005         1.47
# 5   2015-11             1790          1.62            1571         1.63
# 6   2015-12             2558          1.36            1867         1.51
# 7   2016-01             1169          1.51            1991         1.61
# 8   2016-02             2708          1.73            1965         1.55
# 9   2016-03             2884          1.59            1128         1.33
# 10  2016-04             2353          1.47            1237         1.31
# 11  2016-05             2062          1.66            1481         1.51
# 12  2016-06             2567          1.66            1290         1.58
# 13  2016-07             2822          1.35            1946         1.57
# 14  2016-08             2925          1.35            1634         1.20
# 15  2016-09             1007          1.30            1187         1.29
# 16  2016-10             2651          1.62            1319         1.42
# 17  2016-11             1548          1.30            1807         1.57
# 18  2016-12             1083          1.42            1427         1.37
# 19  2017-01             2117          1.47            1411         1.20
# 20  2017-02             1353          1.32            1149         1.63
# 21  2017-03             1161          1.76            1333         1.60
# 22  2017-04             1900          1.71            1212         1.67
# 23  2017-05             1170          1.42            1015         1.68
# 24  2017-06             1575          1.59            1724         1.63
# 25  2017-07             1289          1.67            1926         1.23
# 26  2017-08             1637          1.64            1638         1.30
# 27  2017-09             1986          1.31            1962         1.63
# 28  2017-10             1319          1.30            1047         1.66
# 29  2017-11             1326          1.54            1806         1.36
# 30  2017-12             2887          1.76            1233         1.53
# 31  2018-01             2203          1.73            1443         1.20
# 32  2018-02             1624          1.31            1520         1.36
# 33  2018-03             2078          1.61            1808         1.30
# 34  2018-04             1245          1.66            1604         1.57
# 35  2018-05             1081          1.52            1837         1.67
# 36  2018-06             1111          1.49            1940         1.32
# 37  2018-07             1560          1.38            1659         1.41
# 38  2018-08             2155          1.74            1742         1.41
# 39  2018-09             1312          1.55            1359         1.45
# 40  2018-10             2076          1.79            1986         1.40
# 41  2018-11             2786          1.43            1985         1.54
# 42  2018-12             2948          1.63            1210         1.33
# 43  2019-01             1134          1.35            1407         1.34
# 44  2019-02             2185          1.45            1292         1.59
#
#     melon_shipment  melon_price
# 0              562         3.43
# 1              643         3.39
# 2              561         4.24
# 3             1469         2.59
# 4             1454         3.27
# 5             1163         2.78
# 6              693         3.28
# 7             1250         3.42
# 8             1486         2.78
# 9              787         3.92
# 10             671         3.51
# 11             913         2.63
# 12             439         3.20
# 13             921         3.80
# 14            1164         3.52
# 15             931         3.64
# 16             431         4.21
# 17             808         3.96
# 18            1190         4.40
# 19             839         2.92
# 20             551         2.67
# 21             621         2.50
# 22             944         4.23
# 23             596         3.13
# 24             602         3.00
# 25            1354         3.55
# 26            1202         3.94
# 27             966         3.51
# 28            1232         2.62
# 29             768         3.62
# 30             983         4.30
# 31            1139         3.83
# 32             574         2.53
# 33            1362         3.04
# 34             487         3.58
# 35             989         3.81
# 36             929         3.35
# 37            1147         3.36
# 38             832         3.22
# 39             589         2.89
# 40            1394         3.83
# 41            1478         3.15
# 42             674         3.59
# 43             615         4.31
# 44            1483         3.87

# %% [markdown]
# # Simple use case

# %%
from plot_playground.storytelling.simple_line_date_series_plot import display_plot

# %%
display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple_shipment', 'melon_shipment'], 
    stands_out_columns=['orange_shipment'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\plot_playground\common\data_helper.py in cast_df_column_to_date_str(df, column_name)
#      42         try:
# ---> 43             datetime.strptime(date_str, '%Y-%m-%d')
#      44         except Exception:
#
# ~\Miniconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# ~\Miniconda3\lib\_strptime.py in _strptime(data_string, format)
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#
# ValueError: time data '2015-06' does not match format '%Y-%m-%d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b5c0932f65d6> in <module>()
#       3     date_column='date',
#       4     normal_columns=['apple_shipment', 'melon_shipment'],
# ----> 5     stands_out_columns=['orange_shipment'])
#
# ~\Miniconda3\lib\site-packages\plot_playground\storytelling\simple_line_date_series_plot.py in display_plot(df, date_column, normal_columns, stands_out_columns, width, height, title, title_color, title_font_size, description, description_font_size, description_color, y_axis_label, y_axis_prefix, y_axis_suffix, axis_line_color, axis_text_color, axis_font_size, legend_font_size, legend_color, stands_out_legend_font_size, stands_out_legend_font_color, stands_out_legend_font_weight, line_color, line_size, stands_out_line_color, stands_out_line_size, outer_margin, x_ticks, y_ticks, plot_background_color, plot_margin_left, outer_border_size, outer_border_color, font_family, svg_id)
#     180         stands_out_columns=stands_out_columns)
#     181     df = data_helper.cast_df_column_to_date_str(
# --> 182         df=df, column_name=date_column)
#     183     merged_column_list = [*normal_columns, *stands_out_columns]
#     184     data_helper.validate_null_value_not_exists_in_df(
#
# ~\Miniconda3\lib\site-packages\plot_playground\common\data_helper.py in cast_df_column_to_date_str(df, column_name)
#      45             err_msg = 'It contains a value in the form of an unsupported date: %s' \
#      46                 % date_str
# ---> 47             raise ValueError(err_msg)
#      48         date_str_list[i] = date_str
#      49     df[column_name] = date_str_list
#
# ValueError: It contains a value in the form of an unsupported date: 2015-06

# %% [markdown]
# # Overview
#
# This notebook is used to test on Jupyter via selenium. Please keep state that there is one empty code cell.

# %%
from plot_playground.tests.test_linux_stats_plot import display_test_plot
display_test_plot()
# Out:
# 1

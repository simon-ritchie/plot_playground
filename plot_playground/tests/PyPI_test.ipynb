# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Overview" data-toc-modified-id="Overview-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Overview</a></span></li><li><span><a href="#dev-Install" data-toc-modified-id="dev-Install-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>dev-Install</a></span></li><li><span><a href="#production-install" data-toc-modified-id="production-install-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>production-install</a></span></li><li><span><a href="#storytelling.simple_line_date_series_plot" data-toc-modified-id="storytelling.simple_line_date_series_plot-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>storytelling.simple_line_date_series_plot</a></span></li></ul></div>

# %% [markdown]
# # Overview
#
# This note is used for installation via PyPI and testing of that module.

# %% [markdown]
# # dev-Install

# %%
# !pip uninstall plot_playground --yes
# Out:
# Uninstalling plot-playground-0.0.6:
#   Successfully uninstalled plot-playground-0.0.6

# %%
# !pip install --index-url https://testpypi.python.org/simple/ plot_playground==0.0.8
# Out:
# Looking in indexes: https://testpypi.python.org/simple/
# ...
#   Found existing installation: plot-playground 0.0.7
#     Uninstalling plot-playground-0.0.7:
#       Successfully uninstalled plot-playground-0.0.7
# ...

# %% [markdown]
# # production-install

# %%
# !pip uninstall plot_playground --yes
# Out:
# Uninstalling plot-playground-0.0.8:
#   Successfully uninstalled plot-playground-0.0.8

# %%
# !pip install plot_playground==0.0.8

# %% [markdown]
# # storytelling.simple_line_date_series_plot

# %%
import pandas as pd
from plot_playground.storytelling import simple_line_date_series_plot

df = pd.DataFrame(data=[{
    'date': '2017-11-03',
    'apple': 100,
    'orange': 140,
}, {
    'date': '2017-12-03',
    'apple': 90,
    'orange': 85,
}, {
    'date': '2018-04-03',
    'apple': 120,
    'orange': 170,
}, {
    'date': '2018-09-03',
    'apple': 110,
    'orange': 180,
}, {
    'date': '2019-02-01',
    'apple': 90,
    'orange': 150,
}])

simple_line_date_series_plot.display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple'],
    stands_out_columns=['orange'],
    title='Time series of fruit prices.',
    description='Orange price keeps stable value in the long term.')
# Out:
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
# </script>
# <style>
#
#
# #svg_id_1549855426_899353_61112 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1549855426_899353_61112 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1549855426_899353_61112 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1549855426_899353_61112 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1549855426_899353_61112 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1549855426_899353_61112 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1549855426_899353_61112 .x-axis path,
# #svg_id_1549855426_899353_61112 .y-axis path,
# ...

# %%
df = pd.DataFrame(data=[{
    'date': '2017-11',
    'apple': 100,
    'orange': 140,
}, {
    'date': '2017-12',
    'apple': 90,
    'orange': 85,
}, {
    'date': '2018-04',
    'apple': 120,
    'orange': 170,
}, {
    'date': '2018-09',
    'apple': 110,
    'orange': 180,
}, {
    'date': '2019-02',
    'apple': 90,
    'orange': 150,
}])

simple_line_date_series_plot.display_plot(
    df=df,
    date_column='date',
    normal_columns=['apple'],
    stands_out_columns=['orange'],
    title='Time series of fruit prices.',
    description='Orange price keeps stable value in the long term.')
# Out:
# <script>
#     requirejs.config({
#         paths: {
#             "d3": ["https://d3js.org/d3.v4.min"],
#         },
#     });
# </script>
# <style>
#
#
# #svg_id_1549855427_094352_44904 {
#     border: 1px solid #cccccc;
# }
#
# #svg_id_1549855427_094352_44904 .font {
#     font-family: -apple-system, BlinkMacSystemFont, "Helvetica Neue", YuGothic, "ヒラギノ角ゴ ProN W3", Hiragino Kaku Gothic ProN, Arial, "メイリオ", Meiryo, sans-serif;
# }
#
# #svg_id_1549855427_094352_44904 .title {
#     fill: #6bb2f8;
#     font-size: 25px;
# }
#
# #svg_id_1549855427_094352_44904 .description {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1549855427_094352_44904 .legend {
#     font-size: 14px;
#     fill: #999999;
# }
#
# #svg_id_1549855427_094352_44904 .stands-out-legend {
#     font-size: 14px;
#     fill: #6bb2f8;
#     font-weight: bold;
# }
#
# #svg_id_1549855427_094352_44904 .x-axis path,
# #svg_id_1549855427_094352_44904 .y-axis path,
# ...
